# %%
import pandas as pd
import numpy as np
import tabula
import pymongo
import json
import os

from dotenv import load_dotenv
load_dotenv()

dbuser = "backend"
dbpass = os.environ["backend"]
dbconn = os.environ["connpython"]
origin = os.environ["origin"]

tabs = tabula.read_pdf(origin, pages="7-9", lattice=True, multiple_tables=True, java_options="-Dfile.encoding=UTF8",)
print(f"Found {len(tabs)} tables")

#---

df = tabs[2].copy()
df = df.drop(df.index[[0]])

cid = list(df.columns.values)[0]
cname = list(df.columns.values)[1]
csname = ""

df.columns.values[0] = "Codigo"
df.columns.values[1] = "Atividade"
df.columns.values[2] = "Valor"
df.columns.values[3] = "Porc"
df["Classe"] = cname
df["Subclasse"] = ""

df['Codigo'] = df['Codigo'].fillna("")
df['Valor'] = df['Valor'].fillna("")
df['Porc'] = df['Porc'].fillna("")

doc = df.to_json(orient = "records")
doc = json.loads(doc)

conn = dbconn.replace("<username>", dbuser).replace("<password>", dbpass)
rs = pymongo.MongoClient(conn)

db = rs.legalfees
col = db.fees
col.insert_many(doc)

display(df)
# Out:
# Found 6 tables
#   Codigo                                          Atividade          Valor  \
# 1    6.1                                 Divórcio Judicial:              -
# 2                                             a) Consensual   R$  6.503,84
# 3         b) Cumulado com alimentos e/ou bens, acrescido...   R$  6.503,84
# 4                                              c) Litigioso  R$  10.117,07
# 5         d) Cumulado com alimentos e/ou bens, acrescido...  R$  10.117,07
# 6    6.2                            Reconvenção em divórcio  R$  10.117,07
# 7    6.3  Ação anulatória de separação judicial, divórci...   R$  9.953,08
# 8    6.4  Divórcio extrajudicial em cartório (acrescido ...   R$  3.613,24
# 9    6.5                        Dissolução de união estável
#
#   Porc                                        Classe Subclasse
# 1    -  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES
# 2       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES
# 3   6%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES
# 4       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES
# 5  10%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES
# 6   8%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES
# 7   8%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES
# 8   6%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES
# 9       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES

# %%
del df
df = tabs[3].copy()

c1 = df.columns.values[0].replace("Unnamed: 0","")
c2 = df.columns.values[1]
c3 = df.columns.values[2]
c4 = df.columns.values[3].replace("Unnamed: 1","")

df.columns.values[0] = "Codigo"
df.columns.values[1] = "Atividade"
df.columns.values[2] = "Valor"
df.columns.values[3] = "Porc"

new_row = pd.DataFrame({'Codigo': c1, 'Atividade': c2, 'Valor': c3, 'Porc': c4}, index=[0])
df = pd.concat([new_row,df.loc[:]]).reset_index(drop=True)

df["Classe"] = cname
df["Subclasse"] = csname

df['Codigo'] = df['Codigo'].fillna("")
df['Valor'] = df['Valor'].fillna("")
df['Porc'] = df['Porc'].fillna("")

doc = df.to_json(orient = "records")
doc = json.loads(doc)

conn = dbconn.replace("<username>", dbuser).replace("<password>", dbpass)
rs = pymongo.MongoClient(conn)

db = rs.legalfees
col = db.fees
col.insert_many(doc)

display(df)
# Out:
#    Codigo                                          Atividade          Valor  \
# 0                                              a) Consensual   R$  6.503,84
# 1          b) Cumulada com alimentos e/ou bens, acrescida...   R$  6.503,84
# 2                                               c) Litigiosa  R$  10.117,07
# 3          d) Cumulada com alimentos e/ou bens, acrescida...  R$  10.117,07
# 4     6.6               Investigação de paternidade cumulada              -
# 5          a) com petição de herança, acrescida do percen...  R$  10.117,07
# 6          b) com petição de alimentos, acrescida do perc...  R$  10.117,07
# 7     6.7                      Ação negatória de paternidade  R$  12.285,03
# 8                          a) Ação rescisória de paternidade  R$  12.285,03
# 9     6.8          Ação de nulidade ou anulação de casamento  R$  12.285,03
# 10    6.9  Ação de alimentos: provisórios – provisionais ...
# 11         a) Proposição e/ou contestação – valor de 3 (t...   R$  2.167,95
# 12    6.1     Execução de alimentos – pena de prisão/penhora   R$  2.167,95
# 13         a) Proposição e/ou contestação: valor de 3 (tr...
# 14   6.11                                           Curatela   R$  8.671,79
# 15   6.12                                             Tutela   R$  8.671,79
# 16   6.13                          Emancipação ou suprimento   R$  3.613,24
# 17   6.14    Suprimento judicial de outorga de consentimento   R$  5.058,54
# 18   6.15                                             Adoção              -
# 19                                           a) Por nacional   R$  7.226,48
# 20                                        b) Por estrangeiro  R$  13.730,32
# 21   6.16              Ações cautelares – Direito de Família
# 22                                    a) Arrolamento de bens   R$  5.058,54
# 23         b) Busca e apreensão de crianças e adolescente...   R$  5.058,54
# 24                                      c) Guarda provisória   R$  5.058,54
# 25                              d) Regulamentação de visitas   R$  5.058,54
# 26                                    e) Separação de corpos   R$  5.058,54
# 27                                      f) Sequestro de bens   R$  6.503,84
# 28   6.17        Ação ordinária de regulamentação de visitas   R$  6.503,84
# 29   6.18  Ação ordinária de busca e apreensão de criança...   R$  6.503,84
# 30   6.19                 Ação de interdição ou levantamento   R$  7.226,48
# 31    6.2                        Ação de alteração de guarda   R$  5.058,54
# 32   6.21                       Habeas corpus (prisão civil)  R$  13.730,32
# 33   6.22          Desconsideração da personalidade jurídica   R$  8.671,79
# 34                                     a) Direito Sucessório
# 35   6.23   Inventário, arrolamento e sobrepartilha judicial
# 36         a) Sem litígio: 8% sobre o valor real do monte...   R$  5.058,54
# 37         b) Com litígio: 10% sobre o valor real do mont...   R$  5.058,54
# 38         c) Sobrepartilha: aplicam-se os mesmos índices...
# 39   6.24                                Inventário negativo   R$  3.613,24
#
#    Porc                                        Classe           Subclasse
# 0        ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 1    6%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 2        ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 3   10%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 4     -  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 5        ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 6        ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 7        ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 8        ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 9        ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 10       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 11       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 12       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 13       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 14       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 15       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 16       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 17       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 18    -  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 19       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 20       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 21  20%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 22       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 23       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 24  20%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 25       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 26       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 27       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 28       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 29       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 30       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 31       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 32       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 33  20%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 34       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 35       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 36       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 37       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 38       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 39       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família

# %%
del df
df = tabs[4].copy()

c1 = df.columns.values[0].replace("Unnamed: 0","")
c2 = df.columns.values[1]
c3 = df.columns.values[2]
c4 = df.columns.values[3].replace("Unnamed: 1","")

df.columns.values[0] = "Codigo"
df.columns.values[1] = "Atividade"
df.columns.values[2] = "Valor"
df.columns.values[3] = "Porc"

new_row = pd.DataFrame({'Codigo': c1, 'Atividade': c2, 'Valor': c3, 'Porc': c4}, index=[0])
df = pd.concat([new_row,df.loc[:]]).reset_index(drop=True)

df["Classe"] = cname
df["Subclasse"] = csname

df['Codigo'] = df['Codigo'].fillna("")
df['Valor'] = df['Valor'].fillna("")
df['Porc'] = df['Porc'].fillna("")

doc = df.to_json(orient = "records")
doc = json.loads(doc)

conn = dbconn.replace("<username>", dbuser).replace("<password>", dbpass)
rs = pymongo.MongoClient(conn)

db = rs.legalfees
col = db.fees
col.insert_many(doc)

display(df)
# Out:
#    Codigo                                          Atividade          Valor  \
# 0    6.25  Inventário, arrolamento e sobrepartilha extraj...              -
# 1          a) 6% sobre o valor real do monte-mor ou 6% so...   R$  3.613,24
# 2    6.26                                    Reserva de bens   R$  3.613,24
# 3    6.27                           Remoção de inventariante   R$  8.671,79
# 4    6.28                                    Ação de colação   R$  5.058,54
# 5    6.29  Ação de doação inoficiosa – 10% sobre os bens ...   R$  5.058,54
# 6     6.3                                  Ação de sonegados   R$  8.671,79
# 7    6.31                     Ação de nulidade de testamento  R$  10.117,07
# 8    6.32                      Ação anulatória de testamento  R$  10.117,07
# 9    6.33                       Ação de nulidade de partilha  R$  10.117,07
# 10   6.34  Ação de habilitação de herdeiros (sobre o valo...   R$  3.613,24
# 11   6.35  Ação de habilitação de crédito (sobre o valor ...   R$  3.613,24
# 12   6.36  Ação declaratória de indignidade (sobre o valo...   R$  6.792,89
# 13   6.37  Ação declaratória de deserdação (sobre o quinh...   R$  6.792,89
# 14   6.38                            Retificação de partilha   R$  3.613,24
# 15   6.39  Minuta de testamento e/ou assistência ao ato e...   R$  5.058,54
#
#    Porc                                        Classe           Subclasse
# 0   -.1  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 1        ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 2   10%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 3        ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 4   10%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 5   10%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 6   20%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 7        ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 8        ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 9        ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 10  10%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 11  10%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 12  20%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 13  20%  ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 14       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
# 15       ATIVIDADES EM MATÉRIA DE FAMÍLIA E SUCESSÕES  Direito de Família
