# %%
import pandas as pd
import numpy as np
import tabula
import pymongo
import json
import os

from dotenv import load_dotenv
load_dotenv()

dbuser = "backend"
dbpass = os.environ["backend"]
dbconn = os.environ["connpython"]
origin = os.environ["origin"]

tabs = tabula.read_pdf(origin, pages="6-7", lattice=True, multiple_tables=True, java_options="-Dfile.encoding=UTF8",)
print(f"Found {len(tabs)} tables")

#---

df = tabs[0]
cid = list(df.columns.values)[0]
cname = list(df.columns.values)[1]

df.columns.values[0] = "Codigo"
df.columns.values[1] = "Atividade"
df.columns.values[2] = "Valor"
df.columns.values[3] = "Porc"
df["Classe"] = cname
df["Subclasse"] = ""

df['Codigo'] = df['Codigo'].fillna("")
df['Valor'] = df['Valor'].fillna("")
df['Porc'] = df['Porc'].fillna("")

doc = df.to_json(orient = "records")
doc = json.loads(doc)

conn = dbconn.replace("<username>", dbuser).replace("<password>", dbpass)
rs = pymongo.MongoClient(conn)

db = rs.legalfees
col = db.fees
col.insert_many(doc)

display(df)
# Out:
# Found 7 tables
#    Codigo                                          Atividade         Valor  \
# 0     4.1       Procedimento ordinário: proposição ou defesa  R$  5.203,07
# 1     4.2         Procedimento sumário: proposição ou defesa  R$  3.613,24
# 2     4.3                            Cumprimento de sentença  R$  2.890,60
# 3     4.4              Impugnação ao cumprimento de sentença  R$  2.890,60
# 4     4.5                   Execução de título extrajudicial  R$  2.890,60
# 5     4.6  Impugnação/embargos à execução de título extra...  R$  2.890,60
# 6     4.7  Impugnação/embargos à penhora, à arrematação, ...  R$  2.890,60
# 7     4.8  Processo cautelar específico: incidental ou pr...  R$  2.890,60
# 8     4.9  Processo cautelar inominado: incidental ou pre...  R$  3.613,24
#
#   Porc                       Classe Subclasse
# 0  20%  ATIVIDADES EM MATÉRIA CÍVEL
# 1  20%  ATIVIDADES EM MATÉRIA CÍVEL
# 2  20%  ATIVIDADES EM MATÉRIA CÍVEL
# 3  20%  ATIVIDADES EM MATÉRIA CÍVEL
# 4  20%  ATIVIDADES EM MATÉRIA CÍVEL
# 5  20%  ATIVIDADES EM MATÉRIA CÍVEL
# 6  20%  ATIVIDADES EM MATÉRIA CÍVEL
# 7  10%  ATIVIDADES EM MATÉRIA CÍVEL
# 8  20%  ATIVIDADES EM MATÉRIA CÍVEL

# %%
df = tabs[1]
cid = list(df.columns.values)[0]
csname = list(df.columns.values)[1]

df.columns.values[0] = "Codigo"
df.columns.values[1] = "Atividade"
df.columns.values[2] = "Valor"
df.columns.values[3] = "Porc"
df["Classe"] = cname
df["Subclasse"] = csname

df['Codigo'] = df['Codigo'].fillna("")
df['Valor'] = df['Valor'].fillna("")
df['Porc'] = df['Porc'].fillna("")

doc = df.to_json(orient = "records")
doc = json.loads(doc)

conn = dbconn.replace("<username>", dbuser).replace("<password>", dbpass)
rs = pymongo.MongoClient(conn)

db = rs.legalfees
col = db.fees
col.insert_many(doc)

display(df)
# Out:
#    Codigo                                      Atividade         Valor Porc  \
# 0    4.10                       Consignação em pagamento  R$  3.613,24  20%
# 1    4.11                                       Depósito  R$  2.890,60  10%
# 2    4.12  Anulação e substituição de título ao portador  R$  2.890,60  10%
# 3    4.13                            Prestação de contas  R$  8.671,79
#
#                         Classe                 Subclasse
# 0  ATIVIDADES EM MATÉRIA CÍVEL  Procedimentos Especiais:
# 1  ATIVIDADES EM MATÉRIA CÍVEL  Procedimentos Especiais:
# 2  ATIVIDADES EM MATÉRIA CÍVEL  Procedimentos Especiais:
# 3  ATIVIDADES EM MATÉRIA CÍVEL  Procedimentos Especiais:

# %%
df = tabs[2]
csname = list(df.columns.values)[1]

df.columns.values[0] = "Codigo"
df.columns.values[1] = "Atividade"
df.columns.values[2] = "Valor"
df.columns.values[3] = "Porc"
df["Classe"] = cname
df["Subclasse"] = csname

df['Codigo'] = df['Codigo'].fillna("")
df['Valor'] = df['Valor'].fillna("")
df['Porc'] = df['Porc'].fillna("")

doc = df.to_json(orient = "records")
doc = json.loads(doc)

conn = dbconn.replace("<username>", dbuser).replace("<password>", dbpass)
rs = pymongo.MongoClient(conn)

db = rs.legalfees
col = db.fees
col.insert_many(doc)

display(df)
# Out:
#     Codigo                                          Atividade         Valor  \
# 0     4.14                                              Móvel  R$  2.890,60
# 1     4.15  Imóvel: interdito proibitório – manutenção – r...  R$  5.058,54
# 2     4.16                             Nunciação de obra nova  R$  4.484,52
# 3     4.17                                          Usucapião  R$  5.058,54
# 4     4.18                               Divisão e demarcação  R$  4.484,52
# 5     4.19                               Embargos de terceiro  R$  5.058,54
# 6     4.20                                        Habilitação  R$  3.613,24
# 7     4.21                               Restauração de autos  R$  3.613,24
# 8     4.22        Das vendas a crédito com reserva de domínio  R$  3.613,24
# 9     4.23                                  Do Juízo arbitral  R$  4.484,52
# 10    4.24                                  Da ação monitória  R$  2.562,58
# 11    4.25                              Desapropriação direta  R$  5.125,17
# 12    4.26                            Desapropriação indireta  R$  8.671,79
#
#    Porc                       Classe            Subclasse
# 0   20%  ATIVIDADES EM MATÉRIA CÍVEL  Ações Possessórias:
# 1   20%  ATIVIDADES EM MATÉRIA CÍVEL  Ações Possessórias:
# 2   10%  ATIVIDADES EM MATÉRIA CÍVEL  Ações Possessórias:
# 3   20%  ATIVIDADES EM MATÉRIA CÍVEL  Ações Possessórias:
# 4   10%  ATIVIDADES EM MATÉRIA CÍVEL  Ações Possessórias:
# 5   10%  ATIVIDADES EM MATÉRIA CÍVEL  Ações Possessórias:
# 6   10%  ATIVIDADES EM MATÉRIA CÍVEL  Ações Possessórias:
# 7   10%  ATIVIDADES EM MATÉRIA CÍVEL  Ações Possessórias:
# 8   10%  ATIVIDADES EM MATÉRIA CÍVEL  Ações Possessórias:
# 9   10%  ATIVIDADES EM MATÉRIA CÍVEL  Ações Possessórias:
# 10  10%  ATIVIDADES EM MATÉRIA CÍVEL  Ações Possessórias:
# 11  10%  ATIVIDADES EM MATÉRIA CÍVEL  Ações Possessórias:
# 12  20%  ATIVIDADES EM MATÉRIA CÍVEL  Ações Possessórias:

# %%
df = tabs[3]
csname = list(df.columns.values)[1]

df.columns.values[0] = "Codigo"
df.columns.values[1] = "Atividade"
df.columns.values[2] = "Valor"
df.columns.values[3] = "Porc"
df["Classe"] = cname
df["Subclasse"] = csname

df['Codigo'] = df['Codigo'].fillna("")
df['Valor'] = df['Valor'].fillna("")
df['Porc'] = df['Porc'].fillna("")

doc = df.to_json(orient = "records")
doc = json.loads(doc)

conn = dbconn.replace("<username>", dbuser).replace("<password>", dbpass)
rs = pymongo.MongoClient(conn)

db = rs.legalfees
col = db.fees
col.insert_many(doc)

display(df)
# Out:
#     Codigo                                          Atividade         Valor  \
# 0     4.27                                          Inominada  R$  3.613,24
# 1     4.28            Ação de retificação de registro público  R$  3.613,24
# 2     4.29                                    Alvará judicial  R$  2.562,58
# 3     4.30  Ação de constituição, extinção de usufruto ou ...  R$  3.843,88
# 4     4.31                               Mandado de segurança  R$  5.781,19
# 5     4.32                          Ação ordinária de despejo  R$  4.484,52
# 6     4.33                        Ação renovatória de locação  R$  4.484,52
# 7     4.34       Ação de revisão e/ou arbitramento de aluguel  R$  4.484,52
# 8     4.35                     Ação de consignação de aluguel  R$  3.613,24
# 9     4.36           Atos/acompanhamento despejo/reintegração  R$  2.890,60
# 10    4.37                    Ação de dissolução de sociedade  R$  5.781,19
#
#    Porc                       Classe               Subclasse
# 0   10%  ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 1        ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 2   20%  ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 3   10%  ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 4   20%  ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 5   20%  ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 6   20%  ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 7   20%  ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 8   20%  ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 9        ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 10  20%  ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:

# %%
del df
df = tabs[4].copy()

c1 = df.columns.values[0].replace("Unnamed: 0","")
c2 = df.columns.values[1]
c3 = df.columns.values[2]
c4 = df.columns.values[3].replace("Unnamed: 1","")

df.columns.values[0] = "Codigo"
df.columns.values[1] = "Atividade"
df.columns.values[2] = "Valor"
df.columns.values[3] = "Porc"

new_row = pd.DataFrame({'Codigo': c1, 'Atividade': c2, 'Valor': c3, 'Porc': c4}, index=[0])
df = pd.concat([new_row,df.loc[:]]).reset_index(drop=True)

df["Classe"] = cname
df["Subclasse"] = csname

df['Codigo'] = df['Codigo'].fillna("")
df['Valor'] = df['Valor'].fillna("")
df['Porc'] = df['Porc'].fillna("")

doc = df.to_json(orient = "records")
doc = json.loads(doc)

conn = dbconn.replace("<username>", dbuser).replace("<password>", dbpass)
rs = pymongo.MongoClient(conn)

db = rs.legalfees
col = db.fees
col.insert_many(doc)

display(df)
# Out:
#   Codigo                                          Atividade          Valor  \
# 0   4.38                   Ação de cancelamento de protesto   R$  3.613,24
# 1   4.39                                Mandado de injunção   R$  3.613,24
# 2    4.4                                        Habeas data   R$  3.613,24
# 3   4.41  Ação negatória ou de abstenção de uso de matér...  R$  15.175,62
# 4   4.42  Ação indenizadora por prejuízos decorrentes de...  R$  10.117,08
# 5   4.43  Busca e apreensão em matéria de propriedade in...  R$  12.285,03
# 6   4.44  Procedimentos administrativos de propriedade i...   R$  4.484,52
# 7   4.45  Análise da documentação e pedido de registro d...   R$  3.613,24
# 8   4.46                             Opção de nacionalidade   R$  2.890,60
#
#   Porc                       Classe               Subclasse
# 0  15%  ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 1       ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 2       ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 3    -  ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 4    -  ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 5    -  ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 6    -  ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 7  10%  ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
# 8       ATIVIDADES EM MATÉRIA CÍVEL  Jurisdição Voluntária:
